# %% [markdown]
# # 🏥 Medical Image Segmentation - UNet++ Training (OPTIMIZED)
#
# This notebook trains **UNet++** models with speed optimizations:
# - ✅ Mixed Precision (FP16) - 2x faster
# - ✅ 20 epochs (vs 50) - sufficient for convergence
# - ✅ Auto-save after each training
# - ✅ Resume capability
#
# **Runtime:** ~1.5 hours total (vs 3+ hours before)
#
# ---

# %% [markdown]
# ## Step 1: Setup GPU Runtime
#
# ⚠️ **IMPORTANT:** Make sure you're using a GPU runtime!
# - Go to: **Runtime → Change runtime type → GPU**

# %%
# Verify GPU is available
import torch
print(f"GPU Available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU Name: {torch.cuda.get_device_name(0)}")
    print(f"GPU Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")
else:
    print("⚠️ WARNING: No GPU detected! Training will be very slow.")
# Out:
# GPU Available: True
# GPU Name: Tesla T4
# GPU Memory: 15.83 GB

# %% [markdown]
# ## Step 2: Clone Repository & Install Dependencies

# %%
# Clone the repository
# !git clone https://github.com/Prabhat9801/Medical-Image-Segmentation.git
# %cd Medical-Image-Segmentation

# Install required packages
# !pip install -q timm albumentations opencv-python-headless tqdm
# Out:
# Cloning into 'Medical-Image-Segmentation'...
# remote: Enumerating objects: 78, done.
# remote: Counting objects: 100% (78/78), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 78 (delta 28), reused 67 (delta 21), pack-reused 0 (from 0)
# Receiving objects: 100% (78/78), 1.12 MiB | 4.31 MiB/s, done.
# Resolving deltas: 100% (28/28), done.
# /content/Medical-Image-Segmentation

# %% [markdown]
# ## Step 3: Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Step 4: Extract & Fix Data (Run Once)

# %%
# Run the optimized data extraction script
# !python colab_extract_data.py
# Out:
# 📦 Extracting data with Windows path fix...
# ✅ Extraction complete!
#
# 🔧 Fixing splits.csv paths...
# Before fix - sample path: ../data/processed/isic/images\ISIC_0016024.png
# After fix - sample path: /content/Medical-Image-Segmentation/data/processed/isic/images/ISIC_0016024.png
# ✅ splits.csv paths fixed!
# ✅ Sample files verified - paths are correct!
#
# ============================================================
# 📊 VERIFICATION
# ============================================================
# ✅ Images extracted: 2594
# ✅ Masks extracted: 2594
# ✅ splits.csv: Found
#
# 🎉 Data extraction successful!

# %% [markdown]
# ## Step 5: Helper Function - Save to Drive After Each Training

# %%
import os
import shutil
from datetime import datetime

def save_to_drive(model_name="unetpp"):
    """Save all experiments to Google Drive"""
    drive_dir = f"/content/drive/MyDrive/medical_segmentation_results/{model_name}_experiments"
    local_exp_dir = "/content/Medical-Image-Segmentation/experiments"

    # Create drive directory
    os.makedirs(drive_dir, exist_ok=True)

    # Copy all experiments
    if os.path.exists(local_exp_dir):
        for exp in os.listdir(local_exp_dir):
            src = os.path.join(local_exp_dir, exp)
            dst = os.path.join(drive_dir, exp)

            if os.path.isdir(src):
                # Remove old version if exists
                if os.path.exists(dst):
                    shutil.rmtree(dst)
                # Copy new version
                shutil.copytree(src, dst)
                print(f"✅ Saved: {exp}")

    timestamp = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
    print(f"\n🎉 All results saved to Drive at {timestamp}")
    print(f"📁 Location: {drive_dir}")

def check_already_trained(model_name, data_fraction):
    """Check if this configuration was already trained"""
    drive_dir = f"/content/drive/MyDrive/medical_segmentation_results/{model_name}_experiments"

    if not os.path.exists(drive_dir):
        return False

    # Look for experiments with this model and data fraction
    frac_str = f"{int(data_fraction*100)}pct"
    for exp in os.listdir(drive_dir):
        if model_name in exp and frac_str in exp:
            print(f"⏭️  Skipping {model_name} {frac_str} - already trained!")
            print(f"   Found: {exp}")
            return True

    return False

print("✅ Helper functions loaded!")
# Out:
# ✅ Helper functions loaded!

# %% [markdown]
# ## Step 6: Train UNet++ - 10% Data
#
# **Expected time:** ~8 minutes

# %%
if not check_already_trained("unetpp", 0.1):
    # !python -m src.train \
        --model unetpp \
        --epochs 20 \
        --batch_size 20 \
        --data_fraction 0.1 \
        --lr 1e-4

    # Save immediately to Drive
    save_to_drive("unetpp")
    print("\n✅ UNet++ 10% training complete and saved!")
else:
    print("✅ UNet++ 10% already completed!")
# Out:
# Using device: cuda
# Experiment directory: experiments/unetpp_10pct_20251206_180612
#
# Creating dataloaders...
# /usr/local/lib/python3.12/dist-packages/albumentations/core/validation.py:114: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# /content/Medical-Image-Segmentation/src/datasets/isic_dataset.py:110: UserWarning: Argument(s) 'alpha_affine' are not valid for transform ElasticTransform
#   A.ElasticTransform(p=1.0, alpha=120, sigma=120 * 0.05, alpha_affine=120 * 0.03),
# /content/Medical-Image-Segmentation/src/datasets/isic_dataset.py:112: UserWarning: Argument(s) 'shift_limit' are not valid for transform OpticalDistortion
#   A.OpticalDistortion(distort_limit=1, shift_limit=0.5, p=1.0),
# Loaded 181 samples for train split (fraction: 0.1)
# Loaded 389 samples for val split (fraction: 1.0)
# Loaded 390 samples for test split (fraction: 1.0)
#
# Creating model...
#
# ============================================================
# Model: UNet++
# Total parameters: 9,159,681
# Trainable parameters: 9,159,681
# ============================================================
#
# /content/Medical-Image-Segmentation/src/train.py:217: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler() if device.type == 'cuda' else None
# ✅ Mixed precision training enabled (FP16)
#
# Starting training for 20 epochs...
# ============================================================
#
# Epoch 1 [Train]:   0% 0/10 [00:00<?, ?it/s]/content/Medical-Image-Segmentation/src/train.py:96: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Epoch 1 [Train]: 100% 10/10 [00:08<00:00,  1.12it/s, loss=0.5225, dice=0.8052, iou=0.6739]
# Epoch 1 [Val]: 100% 20/20 [00:06<00:00,  2.90it/s, loss=0.7464, dice=0.1237, iou=0.0659]
#
# Epoch 1/20
#   Train - Loss: 0.6093, Dice: 0.5509, IoU: 0.3911
#   Val   - Loss: 0.6893, Dice: 0.1262, IoU: 0.0682
#   LR: 0.000099
# Checkpoint saved to experiments/unetpp_10pct_20251206_180612/best_model.pt
#   ✓ New best model saved! (Dice: 0.1262)
# ============================================================
#
# Epoch 2 [Train]: 100% 10/10 [00:06<00:00,  1.50it/s, loss=0.6954, dice=0.4005, iou=0.2504]
# Epoch 2 [Val]: 100% 20/20 [00:06<00:00,  2.90it/s, loss=0.7056, dice=0.2014, iou=0.1120]
#
# Epoch 2/20
#   Train - Loss: 0.5686, Dice: 0.6066, IoU: 0.4486
#   Val   - Loss: 0.6564, Dice: 0.1444, IoU: 0.0793
#   LR: 0.000098
# Checkpoint saved to experiments/unetpp_10pct_20251206_180612/best_model.pt
#   ✓ New best model saved! (Dice: 0.1444)
# ============================================================
#
# Epoch 3 [Train]: 100% 10/10 [00:06<00:00,  1.51it/s, loss=0.7986, dice=0.1277, iou=0.0682]
# Epoch 3 [Val]: 100% 20/20 [00:07<00:00,  2.84it/s, loss=0.6659, dice=0.3352, iou=0.2013]
#
# Epoch 3/20
#   Train - Loss: 0.5493, Dice: 0.6149, IoU: 0.4652
#   Val   - Loss: 0.5785, Dice: 0.5427, IoU: 0.3784
#   LR: 0.000095
# Checkpoint saved to experiments/unetpp_10pct_20251206_180612/best_model.pt
#   ✓ New best model saved! (Dice: 0.5427)
# ============================================================
#
# Epoch 4 [Train]: 100% 10/10 [00:06<00:00,  1.50it/s, loss=0.4559, dice=0.7535, iou=0.6045]
# Epoch 4 [Val]: 100% 20/20 [00:07<00:00,  2.80it/s, loss=0.7299, dice=0.4260, iou=0.2706]
#
# Epoch 4/20
#   Train - Loss: 0.5019, Dice: 0.6909, IoU: 0.5307
#   Val   - Loss: 0.5573, Dice: 0.6317, IoU: 0.4665
#   LR: 0.000091
# Checkpoint saved to experiments/unetpp_10pct_20251206_180612/best_model.pt
#   ✓ New best model saved! (Dice: 0.6317)
# ============================================================
#
# Epoch 5 [Train]: 100% 10/10 [00:06<00:00,  1.50it/s, loss=0.4588, dice=0.8013, iou=0.6685]
# Epoch 5 [Val]: 100% 20/20 [00:07<00:00,  2.72it/s, loss=0.7318, dice=0.5074, iou=0.3399]
#
# Epoch 5/20
#   Train - Loss: 0.4957, Dice: 0.6919, IoU: 0.5318
#   Val   - Loss: 0.5201, Dice: 0.6813, IoU: 0.5232
#   LR: 0.000086
# Checkpoint saved to experiments/unetpp_10pct_20251206_180612/best_model.pt
#   ✓ New best model saved! (Dice: 0.6813)
# ============================================================
#
# Epoch 6 [Train]: 100% 10/10 [00:06<00:00,  1.47it/s, loss=0.4484, dice=0.7848, iou=0.6458]
# Epoch 6 [Val]: 100% 20/20 [00:07<00:00,  2.70it/s, loss=0.6660, dice=0.4765, iou=0.3128]
#
# Epoch 6/20
#   Train - Loss: 0.4708, Dice: 0.7321, IoU: 0.5840
#   Val   - Loss: 0.5009, Dice: 0.6953, IoU: 0.5388
#   LR: 0.000080
# Checkpoint saved to experiments/unetpp_10pct_20251206_180612/best_model.pt
#   ✓ New best model saved! (Dice: 0.6953)
# ============================================================
#
# Epoch 7 [Train]: 100% 10/10 [00:06<00:00,  1.49it/s, loss=0.4750, dice=0.8456, iou=0.7325]
# Epoch 7 [Val]: 100% 20/20 [00:07<00:00,  2.76it/s, loss=0.6584, dice=0.5147, iou=0.3465]
#
# Epoch 7/20
#   Train - Loss: 0.4646, Dice: 0.7437, IoU: 0.5953
#   Val   - Loss: 0.4893, Dice: 0.7024, IoU: 0.5464
#   LR: 0.000073
# Checkpoint saved to experiments/unetpp_10pct_20251206_180612/best_model.pt
#   ✓ New best model saved! (Dice: 0.7024)
# ============================================================
#
# Epoch 8 [Train]: 100% 10/10 [00:06<00:00,  1.51it/s, loss=0.5214, dice=0.6572, iou=0.4895]
# Epoch 8 [Val]: 100% 20/20 [00:07<00:00,  2.80it/s, loss=0.6052, dice=0.5925, iou=0.4209]
#
# Epoch 8/20
#   Train - Loss: 0.4619, Dice: 0.7322, IoU: 0.5845
#   Val   - Loss: 0.4597, Dice: 0.7485, IoU: 0.6029
#   LR: 0.000066
# Checkpoint saved to experiments/unetpp_10pct_20251206_180612/best_model.pt
#   ✓ New best model saved! (Dice: 0.7485)
# ============================================================
#
# Epoch 9 [Train]: 100% 10/10 [00:06<00:00,  1.52it/s, loss=0.8875, dice=0.0954, iou=0.0501]
# Epoch 9 [Val]: 100% 20/20 [00:07<00:00,  2.81it/s, loss=0.6350, dice=0.5472, iou=0.3766]
#
# Epoch 9/20
#   Train - Loss: 0.5103, Dice: 0.6869, IoU: 0.5511
#   Val   - Loss: 0.4597, Dice: 0.7492, IoU: 0.6037
#   LR: 0.000058
# Checkpoint saved to experiments/unetpp_10pct_20251206_180612/best_model.pt
#   ✓ New best model saved! (Dice: 0.7492)
# ============================================================
#
# Epoch 10 [Train]: 100% 10/10 [00:06<00:00,  1.51it/s, loss=0.7877, dice=0.1577, iou=0.0856]
# Epoch 10 [Val]: 100% 20/20 [00:07<00:00,  2.79it/s, loss=0.6126, dice=0.5873, iou=0.4157]
#
# Epoch 10/20
#   Train - Loss: 0.4828, Dice: 0.6832, IoU: 0.5439
#   Val   - Loss: 0.4824, Dice: 0.7163, IoU: 0.5615
#   LR: 0.000051
# Checkpoint saved to experiments/unetpp_10pct_20251206_180612/checkpoint_epoch_10.pt
# ============================================================
#
# Epoch 11 [Train]: 100% 10/10 [00:06<00:00,  1.49it/s, loss=0.3511, dice=0.9029, iou=0.8230]
# Epoch 11 [Val]: 100% 20/20 [00:07<00:00,  2.74it/s, loss=0.6575, dice=0.4726, iou=0.3094]
#
# Epoch 11/20
#   Train - Loss: 0.4347, Dice: 0.7742, IoU: 0.6341
#   Val   - Loss: 0.4716, Dice: 0.7075, IoU: 0.5522
#   LR: 0.000043
# ============================================================
#
# Epoch 12 [Train]: 100% 10/10 [00:06<00:00,  1.49it/s, loss=0.7174, dice=0.2769, iou=0.1607]
# Epoch 12 [Val]: 100% 20/20 [00:07<00:00,  2.72it/s, loss=0.5789, dice=0.5900, iou=0.4184]
#
# Epoch 12/20
#   Train - Loss: 0.4653, Dice: 0.7184, IoU: 0.5785
#   Val   - Loss: 0.4592, Dice: 0.7394, IoU: 0.5901
#   LR: 0.000035
# ============================================================
#
# Epoch 13 [Train]: 100% 10/10 [00:06<00:00,  1.49it/s, loss=0.3293, dice=0.9498, iou=0.9044]
# Epoch 13 [Val]: 100% 20/20 [00:07<00:00,  2.68it/s, loss=0.6011, dice=0.5435, iou=0.3731]
#
# Epoch 13/20
#   Train - Loss: 0.4127, Dice: 0.8003, IoU: 0.6728
#   Val   - Loss: 0.4378, Dice: 0.7578, IoU: 0.6143
#   LR: 0.000028
# Checkpoint saved to experiments/unetpp_10pct_20251206_180612/best_model.pt
#   ✓ New best model saved! (Dice: 0.7578)
# ============================================================
#
# Epoch 14 [Train]: 100% 10/10 [00:06<00:00,  1.49it/s, loss=0.3953, dice=0.8062, iou=0.6753]
# Epoch 14 [Val]: 100% 20/20 [00:07<00:00,  2.77it/s, loss=0.5498, dice=0.6101, iou=0.4389]
#
# Epoch 14/20
#   Train - Loss: 0.4211, Dice: 0.7835, IoU: 0.6479
#   Val   - Loss: 0.4282, Dice: 0.7845, IoU: 0.6485
#   LR: 0.000021
# Checkpoint saved to experiments/unetpp_10pct_20251206_180612/best_model.pt
#   ✓ New best model saved! (Dice: 0.7845)
# ============================================================
#
# Epoch 15 [Train]: 100% 10/10 [00:06<00:00,  1.50it/s, loss=0.6424, dice=0.4042, iou=0.2533]
# Epoch 15 [Val]: 100% 20/20 [00:07<00:00,  2.77it/s, loss=0.5777, dice=0.5501, iou=0.3794]
#
# Epoch 15/20
#   Train - Loss: 0.4424, Dice: 0.7458, IoU: 0.6087
#   Val   - Loss: 0.4337, Dice: 0.7658, IoU: 0.6247
#   LR: 0.000015
# ============================================================
#
# Epoch 16 [Train]: 100% 10/10 [00:06<00:00,  1.50it/s, loss=0.7683, dice=0.1543, iou=0.0836]
# Epoch 16 [Val]: 100% 20/20 [00:07<00:00,  2.70it/s, loss=0.5865, dice=0.5801, iou=0.4085]
#
# Epoch 16/20
#   Train - Loss: 0.4485, Dice: 0.7301, IoU: 0.6021
#   Val   - Loss: 0.4414, Dice: 0.7588, IoU: 0.6150
#   LR: 0.000010
# ============================================================
#
# Epoch 17 [Train]: 100% 10/10 [00:06<00:00,  1.50it/s, loss=0.5007, dice=0.6763, iou=0.5110]
# Epoch 17 [Val]: 100% 20/20 [00:07<00:00,  2.78it/s, loss=0.5703, dice=0.5832, iou=0.4116]
#
# Epoch 17/20
#   Train - Loss: 0.4172, Dice: 0.8002, IoU: 0.6699
#   Val   - Loss: 0.4300, Dice: 0.7767, IoU: 0.6388
#   LR: 0.000006
# ============================================================
#
# Epoch 18 [Train]: 100% 10/10 [00:06<00:00,  1.49it/s, loss=0.4839, dice=0.7372, iou=0.5838]
# Epoch 18 [Val]: 100% 20/20 [00:07<00:00,  2.76it/s, loss=0.5887, dice=0.5557, iou=0.3847]
#
# Epoch 18/20
#   Train - Loss: 0.4217, Dice: 0.7879, IoU: 0.6562
#   Val   - Loss: 0.4355, Dice: 0.7653, IoU: 0.6242
#   LR: 0.000003
# ============================================================
#
# Epoch 19 [Train]: 100% 10/10 [00:06<00:00,  1.49it/s, loss=0.4492, dice=0.7286, iou=0.5731]
# Epoch 19 [Val]: 100% 20/20 [00:07<00:00,  2.76it/s, loss=0.5833, dice=0.5556, iou=0.3846]
#
# Epoch 19/20
#   Train - Loss: 0.4193, Dice: 0.7838, IoU: 0.6461
#   Val   - Loss: 0.4348, Dice: 0.7657, IoU: 0.6245
#   LR: 0.000002
# ============================================================
#
# Epoch 20 [Train]: 100% 10/10 [00:06<00:00,  1.49it/s, loss=0.4964, dice=0.6809, iou=0.5162]
# Epoch 20 [Val]: 100% 20/20 [00:07<00:00,  2.77it/s, loss=0.5763, dice=0.5585, iou=0.3874]
#
# Epoch 20/20
#   Train - Loss: 0.4228, Dice: 0.7838, IoU: 0.6504
#   Val   - Loss: 0.4316, Dice: 0.7703, IoU: 0.6310
#   LR: 0.000001
# Checkpoint saved to experiments/unetpp_10pct_20251206_180612/checkpoint_epoch_20.pt
# ============================================================
#
# Checkpoint saved to experiments/unetpp_10pct_20251206_180612/final_model.pt
# Figure saved to experiments/unetpp_10pct_20251206_180612/training_history.png
# Figure(1400x500)
#
# ============================================================
# Training completed!
# Best validation Dice: 0.7845
# Results saved to: experiments/unetpp_10pct_20251206_180612
# ============================================================
#
# ✅ Saved: unetpp_10pct_20251206_180612
#
# 🎉 All results saved to Drive at 2025-12-06 18:11:07
# 📁 Location: /content/drive/MyDrive/medical_segmentation_results/unetpp_experiments
#
# ✅ UNet++ 10% training complete and saved!

# %% [markdown]
# ## Step 7: Train UNet++ - 25% Data
#
# **Expected time:** ~15 minutes

# %%
if not check_already_trained("unetpp", 0.25):
    # !python -m src.train \
        --model unetpp \
        --epochs 20 \
        --batch_size 20 \
        --data_fraction 0.25 \
        --lr 1e-4

    # Save immediately to Drive
    save_to_drive("unetpp")
    print("\n✅ UNet++ 25% training complete and saved!")
else:
    print("✅ UNet++ 25% already completed!")
# Out:
# Using device: cuda
# Experiment directory: experiments/unetpp_25pct_20251206_181110
#
# Creating dataloaders...
# /usr/local/lib/python3.12/dist-packages/albumentations/core/validation.py:114: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# /content/Medical-Image-Segmentation/src/datasets/isic_dataset.py:110: UserWarning: Argument(s) 'alpha_affine' are not valid for transform ElasticTransform
#   A.ElasticTransform(p=1.0, alpha=120, sigma=120 * 0.05, alpha_affine=120 * 0.03),
# /content/Medical-Image-Segmentation/src/datasets/isic_dataset.py:112: UserWarning: Argument(s) 'shift_limit' are not valid for transform OpticalDistortion
#   A.OpticalDistortion(distort_limit=1, shift_limit=0.5, p=1.0),
# Loaded 453 samples for train split (fraction: 0.25)
# Loaded 389 samples for val split (fraction: 1.0)
# Loaded 390 samples for test split (fraction: 1.0)
#
# Creating model...
#
# ============================================================
# Model: UNet++
# Total parameters: 9,159,681
# Trainable parameters: 9,159,681
# ============================================================
#
# /content/Medical-Image-Segmentation/src/train.py:217: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler() if device.type == 'cuda' else None
# ✅ Mixed precision training enabled (FP16)
#
# Starting training for 20 epochs...
# ============================================================
#
# Epoch 1 [Train]:   0% 0/23 [00:00<?, ?it/s]/content/Medical-Image-Segmentation/src/train.py:96: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Epoch 1 [Train]: 100% 23/23 [00:17<00:00,  1.35it/s, loss=0.4380, dice=0.7922, iou=0.6559]
# Epoch 1 [Val]: 100% 20/20 [00:07<00:00,  2.70it/s, loss=0.6729, dice=0.4344, iou=0.2775]
#
# Epoch 1/20
#   Train - Loss: 0.5436, Dice: 0.6029, IoU: 0.4427
#   Val   - Loss: 0.5865, Dice: 0.6628, IoU: 0.5015
#   LR: 0.000099
# Checkpoint saved to experiments/unetpp_25pct_20251206_181110/best_model.pt
#   ✓ New best model saved! (Dice: 0.6628)
# ============================================================
#
# Epoch 2 [Train]: 100% 23/23 [00:16<00:00,  1.40it/s, loss=0.4664, dice=0.6895, iou=0.5261]
# Epoch 2 [Val]: 100% 20/20 [00:07<00:00,  2.75it/s, loss=0.6432, dice=0.5422, iou=0.3720]
#
# Epoch 2/20
#   Train - Loss: 0.4739, Dice: 0.6887, IoU: 0.5298
#   Val   - Loss: 0.4516, Dice: 0.7221, IoU: 0.5699
#   LR: 0.000098
# Checkpoint saved to experiments/unetpp_25pct_20251206_181110/best_model.pt
#   ✓ New best model saved! (Dice: 0.7221)
# ============================================================
#
# Epoch 3 [Train]: 100% 23/23 [00:16<00:00,  1.43it/s, loss=0.5008, dice=0.6491, iou=0.4805]
# Epoch 3 [Val]: 100% 20/20 [00:07<00:00,  2.78it/s, loss=0.5096, dice=0.6915, iou=0.5285]
#
# Epoch 3/20
#   Train - Loss: 0.4322, Dice: 0.7418, IoU: 0.5945
#   Val   - Loss: 0.4006, Dice: 0.7761, IoU: 0.6379
#   LR: 0.000095
# Checkpoint saved to experiments/unetpp_25pct_20251206_181110/best_model.pt
#   ✓ New best model saved! (Dice: 0.7761)
# ============================================================
#
# Epoch 4 [Train]: 100% 23/23 [00:16<00:00,  1.40it/s, loss=0.3993, dice=0.7408, iou=0.5883]
# Epoch 4 [Val]: 100% 20/20 [00:07<00:00,  2.77it/s, loss=0.4791, dice=0.6942, iou=0.5316]
#
# Epoch 4/20
#   Train - Loss: 0.4177, Dice: 0.7504, IoU: 0.6037
#   Val   - Loss: 0.3804, Dice: 0.7829, IoU: 0.6465
#   LR: 0.000091
# Checkpoint saved to experiments/unetpp_25pct_20251206_181110/best_model.pt
#   ✓ New best model saved! (Dice: 0.7829)
# ============================================================
#
# Epoch 5 [Train]: 100% 23/23 [00:16<00:00,  1.42it/s, loss=0.4264, dice=0.6783, iou=0.5132]
# Epoch 5 [Val]: 100% 20/20 [00:07<00:00,  2.73it/s, loss=0.5526, dice=0.6379, iou=0.4683]
#
# Epoch 5/20
#   Train - Loss: 0.4083, Dice: 0.7559, IoU: 0.6118
#   Val   - Loss: 0.3976, Dice: 0.7967, IoU: 0.6647
#   LR: 0.000086
# Checkpoint saved to experiments/unetpp_25pct_20251206_181110/best_model.pt
#   ✓ New best model saved! (Dice: 0.7967)
# ============================================================
#
# Epoch 6 [Train]: 100% 23/23 [00:16<00:00,  1.42it/s, loss=0.4199, dice=0.7261, iou=0.5700]
# Epoch 6 [Val]: 100% 20/20 [00:07<00:00,  2.78it/s, loss=0.5395, dice=0.5926, iou=0.4211]
#
# Epoch 6/20
#   Train - Loss: 0.4023, Dice: 0.7608, IoU: 0.6179
#   Val   - Loss: 0.4028, Dice: 0.7585, IoU: 0.6157
#   LR: 0.000080
# ============================================================
#
# Epoch 7 [Train]: 100% 23/23 [00:16<00:00,  1.43it/s, loss=0.4342, dice=0.6742, iou=0.5085]
# Epoch 7 [Val]: 100% 20/20 [00:07<00:00,  2.78it/s, loss=0.5290, dice=0.6210, iou=0.4503]
#
# Epoch 7/20
#   Train - Loss: 0.3926, Dice: 0.7669, IoU: 0.6276
#   Val   - Loss: 0.3767, Dice: 0.7922, IoU: 0.6621
#   LR: 0.000073
# ============================================================
#
# Epoch 8 [Train]: 100% 23/23 [00:16<00:00,  1.42it/s, loss=0.3017, dice=0.8828, iou=0.7902]
# Epoch 8 [Val]: 100% 20/20 [00:07<00:00,  2.75it/s, loss=0.5283, dice=0.6223, iou=0.4517]
#
# Epoch 8/20
#   Train - Loss: 0.3741, Dice: 0.7950, IoU: 0.6629
#   Val   - Loss: 0.3778, Dice: 0.8076, IoU: 0.6816
#   LR: 0.000066
# Checkpoint saved to experiments/unetpp_25pct_20251206_181110/best_model.pt
#   ✓ New best model saved! (Dice: 0.8076)
# ============================================================
#
# Epoch 9 [Train]: 100% 23/23 [00:16<00:00,  1.43it/s, loss=0.3890, dice=0.7202, iou=0.5627]
# Epoch 9 [Val]: 100% 20/20 [00:07<00:00,  2.78it/s, loss=0.4864, dice=0.6549, iou=0.4869]
#
# Epoch 9/20
#   Train - Loss: 0.3845, Dice: 0.7648, IoU: 0.6227
#   Val   - Loss: 0.3575, Dice: 0.8035, IoU: 0.6753
#   LR: 0.000058
# ============================================================
#
# Epoch 10 [Train]: 100% 23/23 [00:16<00:00,  1.43it/s, loss=0.3532, dice=0.8506, iou=0.7401]
# Epoch 10 [Val]: 100% 20/20 [00:07<00:00,  2.75it/s, loss=0.4873, dice=0.6620, iou=0.4948]
#
# Epoch 10/20
#   Train - Loss: 0.3609, Dice: 0.7993, IoU: 0.6684
#   Val   - Loss: 0.3523, Dice: 0.8089, IoU: 0.6820
#   LR: 0.000051
# Checkpoint saved to experiments/unetpp_25pct_20251206_181110/best_model.pt
#   ✓ New best model saved! (Dice: 0.8089)
# Checkpoint saved to experiments/unetpp_25pct_20251206_181110/checkpoint_epoch_10.pt
# ============================================================
#
# Epoch 11 [Train]: 100% 23/23 [00:16<00:00,  1.43it/s, loss=0.3314, dice=0.8423, iou=0.7276]
# Epoch 11 [Val]: 100% 20/20 [00:07<00:00,  2.77it/s, loss=0.5208, dice=0.6354, iou=0.4657]
#
# Epoch 11/20
#   Train - Loss: 0.3553, Dice: 0.8098, IoU: 0.6848
#   Val   - Loss: 0.3612, Dice: 0.8013, IoU: 0.6728
#   LR: 0.000043
# ============================================================
#
# Epoch 12 [Train]: 100% 23/23 [00:16<00:00,  1.41it/s, loss=0.3903, dice=0.7356, iou=0.5817]
# Epoch 12 [Val]: 100% 20/20 [00:07<00:00,  2.76it/s, loss=0.5449, dice=0.5635, iou=0.3923]
#
# Epoch 12/20
#   Train - Loss: 0.3499, Dice: 0.8091, IoU: 0.6831
#   Val   - Loss: 0.3566, Dice: 0.8052, IoU: 0.6788
#   LR: 0.000035
# ============================================================
#
# Epoch 13 [Train]: 100% 23/23 [00:16<00:00,  1.43it/s, loss=0.4295, dice=0.6836, iou=0.5193]
# Epoch 13 [Val]: 100% 20/20 [00:07<00:00,  2.79it/s, loss=0.5050, dice=0.5878, iou=0.4163]
#
# Epoch 13/20
#   Train - Loss: 0.3533, Dice: 0.8051, IoU: 0.6777
#   Val   - Loss: 0.3471, Dice: 0.8157, IoU: 0.6935
#   LR: 0.000028
# Checkpoint saved to experiments/unetpp_25pct_20251206_181110/best_model.pt
#   ✓ New best model saved! (Dice: 0.8157)
# ============================================================
#
# Epoch 14 [Train]: 100% 23/23 [00:16<00:00,  1.43it/s, loss=0.4358, dice=0.7012, iou=0.5399]
# Epoch 14 [Val]: 100% 20/20 [00:07<00:00,  2.77it/s, loss=0.5265, dice=0.5971, iou=0.4256]
#
# Epoch 14/20
#   Train - Loss: 0.3468, Dice: 0.8091, IoU: 0.6853
#   Val   - Loss: 0.3450, Dice: 0.8195, IoU: 0.6993
#   LR: 0.000021
# Checkpoint saved to experiments/unetpp_25pct_20251206_181110/best_model.pt
#   ✓ New best model saved! (Dice: 0.8195)
# ============================================================
#
# Epoch 15 [Train]: 100% 23/23 [00:16<00:00,  1.41it/s, loss=0.2824, dice=0.8878, iou=0.7982]
# Epoch 15 [Val]: 100% 20/20 [00:07<00:00,  2.77it/s, loss=0.4535, dice=0.6898, iou=0.5265]
#
# Epoch 15/20
#   Train - Loss: 0.3435, Dice: 0.8158, IoU: 0.6974
#   Val   - Loss: 0.3366, Dice: 0.8336, IoU: 0.7179
#   LR: 0.000015
# Checkpoint saved to experiments/unetpp_25pct_20251206_181110/best_model.pt
#   ✓ New best model saved! (Dice: 0.8336)
# ============================================================
#
# Epoch 16 [Train]: 100% 23/23 [00:16<00:00,  1.42it/s, loss=0.3497, dice=0.8350, iou=0.7167]
# Epoch 16 [Val]: 100% 20/20 [00:07<00:00,  2.72it/s, loss=0.4727, dice=0.6489, iou=0.4803]
#
# Epoch 16/20
#   Train - Loss: 0.3364, Dice: 0.8215, IoU: 0.7013
#   Val   - Loss: 0.3294, Dice: 0.8308, IoU: 0.7148
#   LR: 0.000010
# ============================================================
#
# Epoch 17 [Train]: 100% 23/23 [00:16<00:00,  1.43it/s, loss=0.3708, dice=0.7785, iou=0.6373]
# Epoch 17 [Val]: 100% 20/20 [00:07<00:00,  2.77it/s, loss=0.4660, dice=0.6532, iou=0.4850]
#
# Epoch 17/20
#   Train - Loss: 0.3333, Dice: 0.8299, IoU: 0.7116
#   Val   - Loss: 0.3306, Dice: 0.8369, IoU: 0.7232
#   LR: 0.000006
# Checkpoint saved to experiments/unetpp_25pct_20251206_181110/best_model.pt
#   ✓ New best model saved! (Dice: 0.8369)
# ============================================================
#
# Epoch 18 [Train]: 100% 23/23 [00:16<00:00,  1.42it/s, loss=0.2995, dice=0.8947, iou=0.8094]
# Epoch 18 [Val]: 100% 20/20 [00:07<00:00,  2.75it/s, loss=0.4563, dice=0.6622, iou=0.4950]
#
# Epoch 18/20
#   Train - Loss: 0.3297, Dice: 0.8299, IoU: 0.7156
#   Val   - Loss: 0.3308, Dice: 0.8333, IoU: 0.7173
#   LR: 0.000003
# ============================================================
#
# Epoch 19 [Train]: 100% 23/23 [00:16<00:00,  1.41it/s, loss=0.3087, dice=0.8684, iou=0.7674]
# Epoch 19 [Val]: 100% 20/20 [00:07<00:00,  2.77it/s, loss=0.4684, dice=0.6460, iou=0.4771]
#
# Epoch 19/20
#   Train - Loss: 0.3290, Dice: 0.8326, IoU: 0.7168
#   Val   - Loss: 0.3324, Dice: 0.8350, IoU: 0.7202
#   LR: 0.000002
# ============================================================
#
# Epoch 20 [Train]: 100% 23/23 [00:16<00:00,  1.43it/s, loss=0.3738, dice=0.7735, iou=0.6307]
# Epoch 20 [Val]: 100% 20/20 [00:07<00:00,  2.73it/s, loss=0.4609, dice=0.6618, iou=0.4946]
#
# Epoch 20/20
#   Train - Loss: 0.3252, Dice: 0.8443, IoU: 0.7325
#   Val   - Loss: 0.3288, Dice: 0.8358, IoU: 0.7212
#   LR: 0.000001
# Checkpoint saved to experiments/unetpp_25pct_20251206_181110/checkpoint_epoch_20.pt
# ============================================================
#
# Checkpoint saved to experiments/unetpp_25pct_20251206_181110/final_model.pt
# Figure saved to experiments/unetpp_25pct_20251206_181110/training_history.png
# Figure(1400x500)
#
# ============================================================
# Training completed!
# Best validation Dice: 0.8369
# Results saved to: experiments/unetpp_25pct_20251206_181110
# ============================================================
#
# ✅ Saved: unetpp_10pct_20251206_180612
# ✅ Saved: unetpp_25pct_20251206_181110
#
# 🎉 All results saved to Drive at 2025-12-06 18:19:13
# 📁 Location: /content/drive/MyDrive/medical_segmentation_results/unetpp_experiments
#
# ✅ UNet++ 25% training complete and saved!

# %% [markdown]
# ## Step 8: Train UNet++ - 50% Data
#
# **Expected time:** ~25 minutes

# %%
if not check_already_trained("unetpp", 0.5):
    # !python -m src.train \
        --model unetpp \
        --epochs 20 \
        --batch_size 20 \
        --data_fraction 0.5 \
        --lr 1e-4

    # Save immediately to Drive
    save_to_drive("unetpp")
    print("\n✅ UNet++ 50% training complete and saved!")
else:
    print("✅ UNet++ 50% already completed!")
# Out:
# Using device: cuda
# Experiment directory: experiments/unetpp_50pct_20251206_181916
#
# Creating dataloaders...
# /usr/local/lib/python3.12/dist-packages/albumentations/core/validation.py:114: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# /content/Medical-Image-Segmentation/src/datasets/isic_dataset.py:110: UserWarning: Argument(s) 'alpha_affine' are not valid for transform ElasticTransform
#   A.ElasticTransform(p=1.0, alpha=120, sigma=120 * 0.05, alpha_affine=120 * 0.03),
# /content/Medical-Image-Segmentation/src/datasets/isic_dataset.py:112: UserWarning: Argument(s) 'shift_limit' are not valid for transform OpticalDistortion
#   A.OpticalDistortion(distort_limit=1, shift_limit=0.5, p=1.0),
# Loaded 907 samples for train split (fraction: 0.5)
# Loaded 389 samples for val split (fraction: 1.0)
# Loaded 390 samples for test split (fraction: 1.0)
#
# Creating model...
#
# ============================================================
# Model: UNet++
# Total parameters: 9,159,681
# Trainable parameters: 9,159,681
# ============================================================
#
# /content/Medical-Image-Segmentation/src/train.py:217: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler() if device.type == 'cuda' else None
# ✅ Mixed precision training enabled (FP16)
#
# Starting training for 20 epochs...
# ============================================================
#
# Epoch 1 [Train]:   0% 0/46 [00:00<?, ?it/s]/content/Medical-Image-Segmentation/src/train.py:96: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Epoch 1 [Train]: 100% 46/46 [00:34<00:00,  1.35it/s, loss=0.4347, dice=0.7281, iou=0.5724]
# Epoch 1 [Val]: 100% 20/20 [00:07<00:00,  2.62it/s, loss=0.6327, dice=0.4266, iou=0.2711]
#
# Epoch 1/20
#   Train - Loss: 0.5211, Dice: 0.6410, IoU: 0.4789
#   Val   - Loss: 0.4924, Dice: 0.6662, IoU: 0.5038
#   LR: 0.000099
# Checkpoint saved to experiments/unetpp_50pct_20251206_181916/best_model.pt
#   ✓ New best model saved! (Dice: 0.6662)
# ============================================================
#
# Epoch 2 [Train]: 100% 46/46 [00:32<00:00,  1.44it/s, loss=0.3972, dice=0.7856, iou=0.6470]
# Epoch 2 [Val]: 100% 20/20 [00:07<00:00,  2.75it/s, loss=0.5349, dice=0.6183, iou=0.4475]
#
# Epoch 2/20
#   Train - Loss: 0.4475, Dice: 0.7340, IoU: 0.5853
#   Val   - Loss: 0.4272, Dice: 0.7474, IoU: 0.5998
#   LR: 0.000098
# Checkpoint saved to experiments/unetpp_50pct_20251206_181916/best_model.pt
#   ✓ New best model saved! (Dice: 0.7474)
# ============================================================
#
# Epoch 3 [Train]: 100% 46/46 [00:31<00:00,  1.44it/s, loss=0.4107, dice=0.7662, iou=0.6210]
# Epoch 3 [Val]: 100% 20/20 [00:07<00:00,  2.74it/s, loss=0.4931, dice=0.7053, iou=0.5448]
#
# Epoch 3/20
#   Train - Loss: 0.4228, Dice: 0.7481, IoU: 0.6012
#   Val   - Loss: 0.3980, Dice: 0.7873, IoU: 0.6513
#   LR: 0.000095
# Checkpoint saved to experiments/unetpp_50pct_20251206_181916/best_model.pt
#   ✓ New best model saved! (Dice: 0.7873)
# ============================================================
#
# Epoch 4 [Train]: 100% 46/46 [00:31<00:00,  1.44it/s, loss=0.3878, dice=0.7282, iou=0.5725]
# Epoch 4 [Val]: 100% 20/20 [00:07<00:00,  2.77it/s, loss=0.4896, dice=0.6696, iou=0.5034]
#
# Epoch 4/20
#   Train - Loss: 0.4030, Dice: 0.7709, IoU: 0.6327
#   Val   - Loss: 0.3801, Dice: 0.7984, IoU: 0.6663
#   LR: 0.000091
# Checkpoint saved to experiments/unetpp_50pct_20251206_181916/best_model.pt
#   ✓ New best model saved! (Dice: 0.7984)
# ============================================================
#
# Epoch 5 [Train]: 100% 46/46 [00:31<00:00,  1.44it/s, loss=0.3760, dice=0.8232, iou=0.6995]
# Epoch 5 [Val]: 100% 20/20 [00:07<00:00,  2.78it/s, loss=0.4820, dice=0.6663, iou=0.4995]
#
# Epoch 5/20
#   Train - Loss: 0.3848, Dice: 0.7836, IoU: 0.6481
#   Val   - Loss: 0.3677, Dice: 0.8162, IoU: 0.6935
#   LR: 0.000086
# Checkpoint saved to experiments/unetpp_50pct_20251206_181916/best_model.pt
#   ✓ New best model saved! (Dice: 0.8162)
# ============================================================
#
# Epoch 6 [Train]: 100% 46/46 [00:31<00:00,  1.44it/s, loss=0.3123, dice=0.8613, iou=0.7564]
# Epoch 6 [Val]: 100% 20/20 [00:07<00:00,  2.77it/s, loss=0.4826, dice=0.6788, iou=0.5138]
#
# Epoch 6/20
#   Train - Loss: 0.3674, Dice: 0.7957, IoU: 0.6648
#   Val   - Loss: 0.3534, Dice: 0.8289, IoU: 0.7113
#   LR: 0.000080
# Checkpoint saved to experiments/unetpp_50pct_20251206_181916/best_model.pt
#   ✓ New best model saved! (Dice: 0.8289)
# ============================================================
#
# Epoch 7 [Train]: 100% 46/46 [00:32<00:00,  1.43it/s, loss=0.4403, dice=0.6754, iou=0.5099]
# Epoch 7 [Val]: 100% 20/20 [00:07<00:00,  2.76it/s, loss=0.4716, dice=0.6228, iou=0.4522]
#
# Epoch 7/20
#   Train - Loss: 0.3616, Dice: 0.7970, IoU: 0.6673
#   Val   - Loss: 0.3300, Dice: 0.8280, IoU: 0.7113
#   LR: 0.000073
# ============================================================
#
# Epoch 8 [Train]: 100% 46/46 [00:32<00:00,  1.43it/s, loss=0.2953, dice=0.8307, iou=0.7105]
# Epoch 8 [Val]: 100% 20/20 [00:07<00:00,  2.78it/s, loss=0.5263, dice=0.6158, iou=0.4449]
#
# Epoch 8/20
#   Train - Loss: 0.3405, Dice: 0.8202, IoU: 0.6984
#   Val   - Loss: 0.3475, Dice: 0.8265, IoU: 0.7085
#   LR: 0.000066
# ============================================================
#
# Epoch 9 [Train]: 100% 46/46 [00:31<00:00,  1.44it/s, loss=0.4260, dice=0.7630, iou=0.6168]
# Epoch 9 [Val]: 100% 20/20 [00:07<00:00,  2.77it/s, loss=0.4050, dice=0.7726, iou=0.6294]
#
# Epoch 9/20
#   Train - Loss: 0.3471, Dice: 0.8021, IoU: 0.6733
#   Val   - Loss: 0.3141, Dice: 0.8385, IoU: 0.7244
#   LR: 0.000058
# Checkpoint saved to experiments/unetpp_50pct_20251206_181916/best_model.pt
#   ✓ New best model saved! (Dice: 0.8385)
# ============================================================
#
# Epoch 10 [Train]: 100% 46/46 [00:31<00:00,  1.44it/s, loss=0.3414, dice=0.7722, iou=0.6290]
# Epoch 10 [Val]: 100% 20/20 [00:07<00:00,  2.76it/s, loss=0.4390, dice=0.7052, iou=0.5446]
#
# Epoch 10/20
#   Train - Loss: 0.3262, Dice: 0.8271, IoU: 0.7080
#   Val   - Loss: 0.3250, Dice: 0.8286, IoU: 0.7099
#   LR: 0.000051
# Checkpoint saved to experiments/unetpp_50pct_20251206_181916/checkpoint_epoch_10.pt
# ============================================================
#
# Epoch 11 [Train]: 100% 46/46 [00:32<00:00,  1.43it/s, loss=0.3121, dice=0.8551, iou=0.7469]
# Epoch 11 [Val]: 100% 20/20 [00:07<00:00,  2.71it/s, loss=0.4235, dice=0.7234, iou=0.5666]
#
# Epoch 11/20
#   Train - Loss: 0.3173, Dice: 0.8334, IoU: 0.7174
#   Val   - Loss: 0.3154, Dice: 0.8352, IoU: 0.7201
#   LR: 0.000043
# ============================================================
#
# Epoch 12 [Train]: 100% 46/46 [00:31<00:00,  1.44it/s, loss=0.4238, dice=0.6979, iou=0.5359]
# Epoch 12 [Val]: 100% 20/20 [00:07<00:00,  2.68it/s, loss=0.4754, dice=0.6429, iou=0.4737]
#
# Epoch 12/20
#   Train - Loss: 0.3081, Dice: 0.8384, IoU: 0.7253
#   Val   - Loss: 0.3043, Dice: 0.8461, IoU: 0.7373
#   LR: 0.000035
# Checkpoint saved to experiments/unetpp_50pct_20251206_181916/best_model.pt
#   ✓ New best model saved! (Dice: 0.8461)
# ============================================================
#
# Epoch 13 [Train]: 100% 46/46 [00:31<00:00,  1.44it/s, loss=0.3338, dice=0.7605, iou=0.6135]
# Epoch 13 [Val]: 100% 20/20 [00:07<00:00,  2.76it/s, loss=0.3913, dice=0.7415, iou=0.5892]
#
# Epoch 13/20
#   Train - Loss: 0.3040, Dice: 0.8420, IoU: 0.7301
#   Val   - Loss: 0.2936, Dice: 0.8470, IoU: 0.7374
#   LR: 0.000028
# Checkpoint saved to experiments/unetpp_50pct_20251206_181916/best_model.pt
#   ✓ New best model saved! (Dice: 0.8470)
# ============================================================
#
# Epoch 14 [Train]: 100% 46/46 [00:31<00:00,  1.44it/s, loss=0.3186, dice=0.8939, iou=0.8081]
# Epoch 14 [Val]: 100% 20/20 [00:07<00:00,  2.78it/s, loss=0.4216, dice=0.7605, iou=0.6135]
#
# Epoch 14/20
#   Train - Loss: 0.3032, Dice: 0.8424, IoU: 0.7311
#   Val   - Loss: 0.3038, Dice: 0.8529, IoU: 0.7453
#   LR: 0.000021
# Checkpoint saved to experiments/unetpp_50pct_20251206_181916/best_model.pt
#   ✓ New best model saved! (Dice: 0.8529)
# ============================================================
#
# Epoch 15 [Train]: 100% 46/46 [00:31<00:00,  1.44it/s, loss=0.2459, dice=0.9236, iou=0.8581]
# Epoch 15 [Val]: 100% 20/20 [00:07<00:00,  2.77it/s, loss=0.4025, dice=0.7488, iou=0.5984]
#
# Epoch 15/20
#   Train - Loss: 0.2958, Dice: 0.8456, IoU: 0.7366
#   Val   - Loss: 0.2913, Dice: 0.8548, IoU: 0.7484
#   LR: 0.000015
# Checkpoint saved to experiments/unetpp_50pct_20251206_181916/best_model.pt
#   ✓ New best model saved! (Dice: 0.8548)
# ============================================================
#
# Epoch 16 [Train]: 100% 46/46 [00:32<00:00,  1.43it/s, loss=0.2936, dice=0.8802, iou=0.7860]
# Epoch 16 [Val]: 100% 20/20 [00:07<00:00,  2.77it/s, loss=0.4033, dice=0.7474, iou=0.5967]
#
# Epoch 16/20
#   Train - Loss: 0.2915, Dice: 0.8519, IoU: 0.7447
#   Val   - Loss: 0.2876, Dice: 0.8581, IoU: 0.7536
#   LR: 0.000010
# Checkpoint saved to experiments/unetpp_50pct_20251206_181916/best_model.pt
#   ✓ New best model saved! (Dice: 0.8581)
# ============================================================
#
# Epoch 17 [Train]: 100% 46/46 [00:32<00:00,  1.44it/s, loss=0.3229, dice=0.7861, iou=0.6476]
# Epoch 17 [Val]: 100% 20/20 [00:07<00:00,  2.78it/s, loss=0.3800, dice=0.7872, iou=0.6491]
#
# Epoch 17/20
#   Train - Loss: 0.2897, Dice: 0.8512, IoU: 0.7437
#   Val   - Loss: 0.2902, Dice: 0.8518, IoU: 0.7437
#   LR: 0.000006
# ============================================================
#
# Epoch 18 [Train]: 100% 46/46 [00:32<00:00,  1.43it/s, loss=0.3770, dice=0.7231, iou=0.5663]
# Epoch 18 [Val]: 100% 20/20 [00:07<00:00,  2.76it/s, loss=0.3672, dice=0.7867, iou=0.6484]
#
# Epoch 18/20
#   Train - Loss: 0.2874, Dice: 0.8541, IoU: 0.7476
#   Val   - Loss: 0.2799, Dice: 0.8579, IoU: 0.7531
#   LR: 0.000003
# ============================================================
#
# Epoch 19 [Train]: 100% 46/46 [00:31<00:00,  1.44it/s, loss=0.3194, dice=0.7665, iou=0.6214]
# Epoch 19 [Val]: 100% 20/20 [00:07<00:00,  2.78it/s, loss=0.3631, dice=0.7963, iou=0.6615]
#
# Epoch 19/20
#   Train - Loss: 0.2917, Dice: 0.8487, IoU: 0.7394
#   Val   - Loss: 0.2780, Dice: 0.8578, IoU: 0.7530
#   LR: 0.000002
# ============================================================
#
# Epoch 20 [Train]:   4% 2/46 [00:01<00:37,  1.19it/s, loss=0.2629, dice=0.9147, iou=0.8428]

# %% [markdown]
# ## Step 9: Train UNet++ - 100% Data
#
# **Expected time:** ~45 minutes

# %%
if not check_already_trained("unetpp", 1.0):
    # !python -m src.train \
        --model unetpp \
        --epochs 20 \
        --batch_size 20 \
        --data_fraction 1.0 \
        --lr 1e-4

    # Save immediately to Drive
    save_to_drive("unetpp")
    print("\n✅ UNet++ 100% training complete and saved!")
else:
    print("✅ UNet++ 100% already completed!")
# Out:
# Using device: cuda
# Experiment directory: experiments/unetpp_100pct_20251206_183240
#
# Creating dataloaders...
# /usr/local/lib/python3.12/dist-packages/albumentations/core/validation.py:114: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# /content/Medical-Image-Segmentation/src/datasets/isic_dataset.py:110: UserWarning: Argument(s) 'alpha_affine' are not valid for transform ElasticTransform
#   A.ElasticTransform(p=1.0, alpha=120, sigma=120 * 0.05, alpha_affine=120 * 0.03),
# /content/Medical-Image-Segmentation/src/datasets/isic_dataset.py:112: UserWarning: Argument(s) 'shift_limit' are not valid for transform OpticalDistortion
#   A.OpticalDistortion(distort_limit=1, shift_limit=0.5, p=1.0),
# Loaded 1815 samples for train split (fraction: 1.0)
# Loaded 389 samples for val split (fraction: 1.0)
# Loaded 390 samples for test split (fraction: 1.0)
#
# Creating model...
#
# ============================================================
# Model: UNet++
# Total parameters: 9,159,681
# Trainable parameters: 9,159,681
# ============================================================
#
# /content/Medical-Image-Segmentation/src/train.py:217: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler() if device.type == 'cuda' else None
# ✅ Mixed precision training enabled (FP16)
#
# Starting training for 20 epochs...
# ============================================================
#
# Epoch 1 [Train]:   0% 0/91 [00:00<?, ?it/s]/content/Medical-Image-Segmentation/src/train.py:96: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Epoch 1 [Train]: 100% 91/91 [01:05<00:00,  1.39it/s, loss=0.4636, dice=0.7107, iou=0.5512]
# Epoch 1 [Val]: 100% 20/20 [00:07<00:00,  2.78it/s, loss=0.5726, dice=0.5702, iou=0.3988]
#
# Epoch 1/20
#   Train - Loss: 0.5233, Dice: 0.6573, IoU: 0.5006
#   Val   - Loss: 0.4564, Dice: 0.7440, IoU: 0.5965
#   LR: 0.000099
# Checkpoint saved to experiments/unetpp_100pct_20251206_183240/best_model.pt
#   ✓ New best model saved! (Dice: 0.7440)
# ============================================================
#
# Epoch 2 [Train]: 100% 91/91 [01:03<00:00,  1.43it/s, loss=0.4109, dice=0.8545, iou=0.7460]
# Epoch 2 [Val]: 100% 20/20 [00:07<00:00,  2.77it/s, loss=0.5424, dice=0.6023, iou=0.4309]
#
# Epoch 2/20
#   Train - Loss: 0.4483, Dice: 0.7462, IoU: 0.5988
#   Val   - Loss: 0.4484, Dice: 0.7419, IoU: 0.5926
#   LR: 0.000098
# ============================================================
#
# Epoch 3 [Train]: 100% 91/91 [01:03<00:00,  1.43it/s, loss=0.3526, dice=0.8529, iou=0.7436]
# Epoch 3 [Val]: 100% 20/20 [00:07<00:00,  2.79it/s, loss=0.4387, dice=0.7243, iou=0.5677]
#
# Epoch 3/20
#   Train - Loss: 0.4139, Dice: 0.7710, IoU: 0.6321
#   Val   - Loss: 0.3806, Dice: 0.7940, IoU: 0.6610
#   LR: 0.000095
# Checkpoint saved to experiments/unetpp_100pct_20251206_183240/best_model.pt
#   ✓ New best model saved! (Dice: 0.7940)
# ============================================================
#
# Epoch 4 [Train]: 100% 91/91 [01:03<00:00,  1.44it/s, loss=0.3172, dice=0.8624, iou=0.7580]
# Epoch 4 [Val]: 100% 20/20 [00:07<00:00,  2.76it/s, loss=0.4592, dice=0.6513, iou=0.4829]
#
# Epoch 4/20
#   Train - Loss: 0.3875, Dice: 0.7850, IoU: 0.6495
#   Val   - Loss: 0.3562, Dice: 0.8159, IoU: 0.6918
#   LR: 0.000091
# Checkpoint saved to experiments/unetpp_100pct_20251206_183240/best_model.pt
#   ✓ New best model saved! (Dice: 0.8159)
# ============================================================
#
# Epoch 5 [Train]: 100% 91/91 [01:03<00:00,  1.44it/s, loss=0.3986, dice=0.7771, iou=0.6354]
# Epoch 5 [Val]: 100% 20/20 [00:07<00:00,  2.77it/s, loss=0.4365, dice=0.6749, iou=0.5094]
#
# Epoch 5/20
#   Train - Loss: 0.3640, Dice: 0.8013, IoU: 0.6730
#   Val   - Loss: 0.3447, Dice: 0.8300, IoU: 0.7117
#   LR: 0.000086
# Checkpoint saved to experiments/unetpp_100pct_20251206_183240/best_model.pt
#   ✓ New best model saved! (Dice: 0.8300)
# ============================================================
#
# Epoch 6 [Train]: 100% 91/91 [01:03<00:00,  1.43it/s, loss=0.3289, dice=0.8274, iou=0.7056]
# Epoch 6 [Val]: 100% 20/20 [00:07<00:00,  2.79it/s, loss=0.4438, dice=0.6453, iou=0.4763]
#
# Epoch 6/20
#   Train - Loss: 0.3456, Dice: 0.8063, IoU: 0.6792
#   Val   - Loss: 0.3271, Dice: 0.8361, IoU: 0.7220
#   LR: 0.000080
# Checkpoint saved to experiments/unetpp_100pct_20251206_183240/best_model.pt
#   ✓ New best model saved! (Dice: 0.8361)
# ============================================================
#
# Epoch 7 [Train]: 100% 91/91 [01:03<00:00,  1.43it/s, loss=0.3180, dice=0.8223, iou=0.6982]
# Epoch 7 [Val]: 100% 20/20 [00:07<00:00,  2.78it/s, loss=0.4707, dice=0.6163, iou=0.4454]
#
# Epoch 7/20
#   Train - Loss: 0.3226, Dice: 0.8221, IoU: 0.7014
#   Val   - Loss: 0.3141, Dice: 0.8213, IoU: 0.6999
#   LR: 0.000073
# ============================================================
#
# Epoch 8 [Train]: 100% 91/91 [01:03<00:00,  1.44it/s, loss=0.3982, dice=0.7008, iou=0.5394]
# Epoch 8 [Val]: 100% 20/20 [00:07<00:00,  2.76it/s, loss=0.3934, dice=0.6940, iou=0.5314]
#
# Epoch 8/20
#   Train - Loss: 0.3154, Dice: 0.8206, IoU: 0.6997
#   Val   - Loss: 0.2924, Dice: 0.8532, IoU: 0.7466
#   LR: 0.000066
# Checkpoint saved to experiments/unetpp_100pct_20251206_183240/best_model.pt
#   ✓ New best model saved! (Dice: 0.8532)
# ============================================================
#
# Epoch 9 [Train]: 100% 91/91 [01:03<00:00,  1.44it/s, loss=0.2830, dice=0.8650, iou=0.7620]
# Epoch 9 [Val]: 100% 20/20 [00:07<00:00,  2.76it/s, loss=0.3734, dice=0.7384, iou=0.5853]
#
# Epoch 9/20
#   Train - Loss: 0.3010, Dice: 0.8274, IoU: 0.7092
#   Val   - Loss: 0.2934, Dice: 0.8312, IoU: 0.7131
#   LR: 0.000058
# ============================================================
#
# Epoch 10 [Train]: 100% 91/91 [01:03<00:00,  1.43it/s, loss=0.2903, dice=0.8635, iou=0.7597]
# Epoch 10 [Val]: 100% 20/20 [00:07<00:00,  2.79it/s, loss=0.3991, dice=0.6805, iou=0.5157]
#
# Epoch 10/20
#   Train - Loss: 0.2886, Dice: 0.8311, IoU: 0.7142
#   Val   - Loss: 0.2839, Dice: 0.8387, IoU: 0.7249
#   LR: 0.000051
# Checkpoint saved to experiments/unetpp_100pct_20251206_183240/checkpoint_epoch_10.pt
# ============================================================
#
# Epoch 11 [Train]: 100% 91/91 [01:03<00:00,  1.43it/s, loss=0.2342, dice=0.8915, iou=0.8042]
# Epoch 11 [Val]: 100% 20/20 [00:07<00:00,  2.77it/s, loss=0.3291, dice=0.7510, iou=0.6013]
#
# Epoch 11/20
#   Train - Loss: 0.2775, Dice: 0.8396, IoU: 0.7262
#   Val   - Loss: 0.2629, Dice: 0.8606, IoU: 0.7571
#   LR: 0.000043
# Checkpoint saved to experiments/unetpp_100pct_20251206_183240/best_model.pt
#   ✓ New best model saved! (Dice: 0.8606)
# ============================================================
#
# Epoch 12 [Train]: 100% 91/91 [01:03<00:00,  1.44it/s, loss=0.2371, dice=0.9081, iou=0.8316]
# Epoch 12 [Val]: 100% 20/20 [00:07<00:00,  2.76it/s, loss=0.3435, dice=0.7476, iou=0.5969]
#
# Epoch 12/20
#   Train - Loss: 0.2664, Dice: 0.8473, IoU: 0.7375
#   Val   - Loss: 0.2581, Dice: 0.8569, IoU: 0.7513
#   LR: 0.000035
# ============================================================
#
# Epoch 13 [Train]: 100% 91/91 [01:03<00:00,  1.43it/s, loss=0.2304, dice=0.8762, iou=0.7797]
# Epoch 13 [Val]: 100% 20/20 [00:07<00:00,  2.72it/s, loss=0.3334, dice=0.7400, iou=0.5873]
#
# Epoch 13/20
#   Train - Loss: 0.2627, Dice: 0.8471, IoU: 0.7384
#   Val   - Loss: 0.2580, Dice: 0.8537, IoU: 0.7465
#   LR: 0.000028
# ============================================================
#
# Epoch 14 [Train]: 100% 91/91 [01:03<00:00,  1.43it/s, loss=0.2778, dice=0.8453, iou=0.7321]
# Epoch 14 [Val]: 100% 20/20 [00:07<00:00,  2.78it/s, loss=0.4148, dice=0.6365, iou=0.4668]
#
# Epoch 14/20
#   Train - Loss: 0.2559, Dice: 0.8508, IoU: 0.7431
#   Val   - Loss: 0.2585, Dice: 0.8478, IoU: 0.7391
#   LR: 0.000021
# ============================================================
#
# Epoch 15 [Train]: 100% 91/91 [01:03<00:00,  1.44it/s, loss=0.2548, dice=0.8416, iou=0.7266]
# Epoch 15 [Val]: 100% 20/20 [00:07<00:00,  2.75it/s, loss=0.3370, dice=0.7387, iou=0.5856]
#
# Epoch 15/20
#   Train - Loss: 0.2461, Dice: 0.8618, IoU: 0.7600
#   Val   - Loss: 0.2445, Dice: 0.8680, IoU: 0.7685
#   LR: 0.000015
# Checkpoint saved to experiments/unetpp_100pct_20251206_183240/best_model.pt
#   ✓ New best model saved! (Dice: 0.8680)
# ============================================================
#
# Epoch 16 [Train]: 100% 91/91 [01:03<00:00,  1.43it/s, loss=0.2711, dice=0.8390, iou=0.7227]
# Epoch 16 [Val]: 100% 20/20 [00:07<00:00,  2.76it/s, loss=0.3114, dice=0.7893, iou=0.6519]
#
# Epoch 16/20
#   Train - Loss: 0.2426, Dice: 0.8634, IoU: 0.7617
#   Val   - Loss: 0.2446, Dice: 0.8628, IoU: 0.7598
#   LR: 0.000010
# ============================================================
#
# Epoch 17 [Train]: 100% 91/91 [01:03<00:00,  1.43it/s, loss=0.1983, dice=0.8972, iou=0.8136]
# Epoch 17 [Val]: 100% 20/20 [00:07<00:00,  2.72it/s, loss=0.3462, dice=0.6947, iou=0.5322]
#
# Epoch 17/20
#   Train - Loss: 0.2373, Dice: 0.8678, IoU: 0.7692
#   Val   - Loss: 0.2343, Dice: 0.8689, IoU: 0.7709
#   LR: 0.000006
# Checkpoint saved to experiments/unetpp_100pct_20251206_183240/best_model.pt
#   ✓ New best model saved! (Dice: 0.8689)
# ============================================================
#
# Epoch 18 [Train]: 100% 91/91 [01:03<00:00,  1.44it/s, loss=0.3175, dice=0.7335, iou=0.5791]
# Epoch 18 [Val]: 100% 20/20 [00:07<00:00,  2.77it/s, loss=0.3103, dice=0.7680, iou=0.6234]
#
# Epoch 18/20
#   Train - Loss: 0.2343, Dice: 0.8723, IoU: 0.7757
#   Val   - Loss: 0.2304, Dice: 0.8756, IoU: 0.7803
#   LR: 0.000003
# Checkpoint saved to experiments/unetpp_100pct_20251206_183240/best_model.pt
#   ✓ New best model saved! (Dice: 0.8756)
# ============================================================
#
# Epoch 19 [Train]: 100% 91/91 [01:03<00:00,  1.44it/s, loss=0.3727, dice=0.6948, iou=0.5323]
# Epoch 19 [Val]: 100% 20/20 [00:07<00:00,  2.76it/s, loss=0.3341, dice=0.7363, iou=0.5826]
#
# Epoch 19/20
#   Train - Loss: 0.2360, Dice: 0.8664, IoU: 0.7671
#   Val   - Loss: 0.2341, Dice: 0.8714, IoU: 0.7740
#   LR: 0.000002
# ============================================================
#
# Epoch 20 [Train]: 100% 91/91 [01:03<00:00,  1.43it/s, loss=0.2429, dice=0.8603, iou=0.7549]
# Epoch 20 [Val]: 100% 20/20 [00:07<00:00,  2.77it/s, loss=0.3224, dice=0.7474, iou=0.5967]
#
# Epoch 20/20
#   Train - Loss: 0.2329, Dice: 0.8746, IoU: 0.7785
#   Val   - Loss: 0.2307, Dice: 0.8737, IoU: 0.7775
#   LR: 0.000001
# Checkpoint saved to experiments/unetpp_100pct_20251206_183240/checkpoint_epoch_20.pt
# ============================================================
#
# Checkpoint saved to experiments/unetpp_100pct_20251206_183240/final_model.pt
# Figure saved to experiments/unetpp_100pct_20251206_183240/training_history.png
# Figure(1400x500)
#
# ============================================================
# Training completed!
# Best validation Dice: 0.8756
# Results saved to: experiments/unetpp_100pct_20251206_183240
# ============================================================
#
# ✅ Saved: unetpp_50pct_20251206_181916
# ✅ Saved: unetpp_10pct_20251206_180612
# ✅ Saved: unetpp_25pct_20251206_181110
# ✅ Saved: unetpp_100pct_20251206_183240
#
# 🎉 All results saved to Drive at 2025-12-06 18:56:34
# 📁 Location: /content/drive/MyDrive/medical_segmentation_results/unetpp_experiments
#
# ✅ UNet++ 100% training complete and saved!

# %% [markdown]
# ## Step 10: Final Summary

# %%
import os

drive_dir = "/content/drive/MyDrive/medical_segmentation_results/unetpp_experiments"

print("="*60)
print("🎉 UNet++ Training Complete!")
print("="*60)

if os.path.exists(drive_dir):
    experiments = [d for d in os.listdir(drive_dir) if os.path.isdir(os.path.join(drive_dir, d))]
    print(f"\n✅ Total experiments saved: {len(experiments)}")
    print(f"\n📁 Saved experiments:")
    for exp in sorted(experiments):
        print(f"   - {exp}")
    print(f"\n📍 Location: {drive_dir}")
else:
    print("\n⚠️ No experiments found in Drive")

print("\n" + "="*60)
print("Next steps:")
print("1. Run COLAB_TRAIN_TRANSUNET.ipynb to train TransUNet")
print("2. Run COLAB_RESULTS.ipynb to evaluate all models")
print("="*60)
# Out:
# ============================================================
# 🎉 UNet++ Training Complete!
# ============================================================
#
# ✅ Total experiments saved: 4
#
# 📁 Saved experiments:
#    - unetpp_100pct_20251206_183240
#    - unetpp_10pct_20251206_180612
#    - unetpp_25pct_20251206_181110
#    - unetpp_50pct_20251206_181916
#
# 📍 Location: /content/drive/MyDrive/medical_segmentation_results/unetpp_experiments
#
# ============================================================
# Next steps:
# 1. Run COLAB_TRAIN_TRANSUNET.ipynb to train TransUNet
# 2. Run COLAB_RESULTS.ipynb to evaluate all models
# ============================================================
